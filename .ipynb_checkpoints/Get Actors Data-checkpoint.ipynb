# %%
import requests
import re
import json
import logging
from bs4 import BeautifulSoup as bs
'''
with open('/Users/daeyeop/Work/KBS Drama project/Data/drama.json', 'r', encoding='utf-8') as f:
    drama = json.load(f)
    drama = set(drama)

with open('/Users/daeyeop/Work/KBS Drama project/Data/actors.json', 'r', encoding='utf-8') as f:
    actors = json.load(f)
    actors = set(actors)
'''
drama = set([])
actors = set([])

base_url = 'https://search.naver.com/search.naver'
logging.basicConfig(filename='Drama.log', level=10, format='%(asctime)s:%(message)s')

def get_soup(url):
    html = requests.get(url)
    assert html.status_code == 200, 'Response needs to be 200, but {}'.format(html)
    soup = bs(html.content, 'html.parser')
    
    return soup


def get_cast_url(drama_url):
    soup = get_soup(drama_url)
    url_list = soup.find('ul',{'class':'tab_list'})
    for i in url_list.find_all('a'):
        try:
            url = i.attrs['href']
        except:
            logging.info('drama_url : {}, no attrs, in {}'.format(i, get_cast_url.__cast__))
            return None
        else:
            if 'cast%' in url:
                cast_url = base_url+url
    return cast_url


def isdrama(url):
    soup = get_soup(url)
    try:
        genre = soup.find('div', {'class':'sub_title'}).next.next.text
    except:
        return False
    if genre == '드라마':
        return True
    return False


def get_drama_urls(actor_url):
    
    pre_len_drama_set = len(drama)
    drama_url_list = []
    soup = get_soup(actor_url)
    result = soup.find('div',{'class':'workact_dsc'})
    try:
        drama_data = result.text.split('oPagingListUi76.displayResult(')[1].split('}]')[0]
    except:
        logging.info('actor_url : {}, no displayResult, in {}'.format(actor_url, get_drama_urls.__name__))
        return None
    for i in drama_data.split('\"onair_url\": \"'):
        if i.startswith('https://search.naver.com/search'):
            drama_url = i.split("\"")[0]
            if isdrama(drama_url) and not drama_url in drama:
                drama_url_list.append(drama_url) 
                drama.add(drama_url)
                print_title(drama_url)
    
    if len(drama_url_list) == 0:
        return None
    if pre_len_drama_set == len(drama):
        return None

    return drama_url_list


def get_actor_urls(cast_url):
    pre_len_actors_set = len(actors)
    actor_url_list = []
    people_search = 'https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query={query}&os={os}&ie=utf8&key=PeopleService'
    soup = get_soup(cast_url)
    
    url_list = soup.find('div',{'class':"list_image_info"})
    url_list_parts = url_list.find_all('span',{'class':'sub_text type_ell_2 _html_ellipsis'})
    if (url_list_parts) == 0:
        logging.info('cast_url : {}, len is 0, in {}'.format(cast_url, get_actor_urls.__name__))
        return None
    for i in url_list_parts:
        try:
            url = i.a.attrs['href']
            url = url.split('&')
            for part in url:
                if part.startswith('os'):
                    os = part.split('=')[-1]
                elif part.startswith('query'):
                    query = part.split('=')[-1]
        except Exception as e:
            logging.info('actor_url : {}, error is {} in {}'.format(i, e, get_actor_urls.__name__))
            
        else:
            actor_url = people_search.format(query=query, os=os)
            
            if actor_url not in actors:
                actors.add(actor_url)
                actor_url_list.append(actor_url)
                print_title(actor_url)
        
    if len(actor_url_list) == 0:
        return None
    if pre_len_actors_set == len(actors):
        return None
    
    return actor_url_list

def save(google_drive=True, local_drive=True):
    
    drama_file = 'drama_edited.json'
    actor_file = 'actor_edited.json'
    
    if google_drive:
        with open('/Users/daeyeop/Google Drive File Stream/My drive/코어닷_드라마/{}'.format(drama_file), 'w', encoding='utf-8') as f:
            json.dump(list(drama), f, indent='\t')
        with open('/Users/daeyeop/Google Drive File Stream/My drive/코어닷_드라마/{}'.format(actor_file), 'w', encoding='utf-8') as f:
            json.dump(list(actors), f, indent='\t')
            
        print('drama : {}, actors : {} are saved in google_drive'.format(len(drama), len(actors)))
    
    if local_drive:
        with open('/Users/daeyeop/Work/KBS Drama project/Data/{}'.format(drama_file) , 'w', encoding='utf-8') as f:
            json.dump(list(drama), f, indent='\t')
        with open('/Users/daeyeop/Work/KBS Drama project/Data/{}'.format(actor_file), 'w', encoding='utf-8') as f:
            json.dump(list(actors), f, indent='\t')

    print('drama : {}, actors : {} are saved in local_drive'.format(len(drama), len(actors)))

def crawler(actor_url):
    drama_url_list = get_drama_urls(actor_url)  ### drama.add(drama_urls)
    if drama_url_list is None:
        return None
    for drama_url in drama_url_list:
        cast_url = get_cast_url(drama_url)
        actor_url_list = get_actor_urls(cast_url) ### actors.add(actor_url)
        print(drama_url)
        if actor_url_list is None:
            return None
        for actor_url in actor_url_list:
            crawler(actor_url)
            save()
            
def print_title(url):
    soup = get_soup(url)
    print(soup.title.text)

# %%
drama
# Out:
# set()

# %%
new_act = 'https://people.search.naver.com/search.naver?where=nexearch&query=신성록&sm=tab_etc&ie=utf8&key=PeopleService&os=115385'
crawler(new_act)
# Out:
# 카이로스 : 네이버 통합검색
# 배가본드 : 네이버 통합검색
# 퍼퓸 : 네이버 통합검색
# 황후의품격 : 네이버 통합검색
# 신성록 :: 네이버 인물검색
# 영화배우 이세영 :: 네이버 인물검색
# 안보현 :: 네이버 인물검색
# 남규리 :: 네이버 인물검색
# WINNER 강승윤 :: 네이버 인물검색
# 이주명 :: 네이버 인물검색
# 황정민 :: 네이버 인물검색
# 신구 :: 네이버 인물검색
# 고규필 :: 네이버 인물검색
# 조동인 :: 네이버 인물검색
# 임철형 :: 네이버 인물검색
# 소희정 :: 네이버 인물검색
# 탤런트 이태구 :: 네이버 인물검색
# 이시언 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214012462%22%7D&pkid=57&os=14012462&query=%EC%B9%B4%EC%9D%B4%EB%A1%9C%EC%8A%A4
# drama : 4, actors : 14 are saved in google_drive
# drama : 4, actors : 14 are saved in local_drive
# 메모리스트 : 네이버 통합검색
# 의사요한 : 네이버 통합검색
# 왕이된남자 : 네이버 통합검색
# 유승호 :: 네이버 인물검색
# 조성하 :: 네이버 인물검색
# 고창석 :: 네이버 인물검색
# 윤지온 :: 네이버 인물검색
# 전효성 :: 네이버 인물검색
# 조한철 :: 네이버 인물검색
# 손광업 :: 네이버 인물검색
# 박응수 :: 네이버 인물검색
# 오치운 :: 네이버 인물검색
# 김서경 :: 네이버 인물검색
# 정하준 :: 네이버 인물검색
# 문정기 :: 네이버 인물검색
# 임세주 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2211813504%22%7D&pkid=57&os=11813504&query=%EB%A9%94%EB%AA%A8%EB%A6%AC%EC%8A%A4%ED%8A%B8
# 복수가돌아왔다 : 네이버 통합검색
# 로봇이아니야 : 네이버 통합검색
# 군주가면의주인 : 네이버 통합검색
# 리멤버아들의전쟁 : 네이버 통합검색
# 조보아 :: 네이버 인물검색
# 곽동연 :: 네이버 인물검색
# 김동영 :: 네이버 인물검색
# 박아인 :: 네이버 인물검색
# 김미경 :: 네이버 인물검색
# 김재화 :: 네이버 인물검색
# 최원홍 :: 네이버 인물검색
# 김영옥 :: 네이버 인물검색
# 조엘 로버츠 :: 네이버 인물검색
# 김여진 :: 네이버 인물검색
# 연준석 :: 네이버 인물검색
# 이성우 :: 네이버 인물검색
# 유선호 :: 네이버 인물검색
# 오희준 :: 네이버 인물검색
# 탤런트 장동주 :: 네이버 인물검색
# 김다예 :: 네이버 인물검색
# 홍승범 :: 네이버 인물검색
# 천호진 :: 네이버 인물검색
# 조현식 :: 네이버 인물검색
# 엄효섭 :: 네이버 인물검색
# 김광규 :: 네이버 인물검색
# 김도연 :: 네이버 인물검색
# 박경혜 :: 네이버 인물검색
# 장원영 :: 네이버 인물검색
# 김결 :: 네이버 인물검색
# 신담수 :: 네이버 인물검색
# 채송아 :: 네이버 인물검색
# 전수경 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228723136%22%7D&pkid=57&os=8723136&query=%EB%B3%B5%EC%88%98%EA%B0%80%EB%8F%8C%EC%95%84%EC%99%94%EB%8B%A4
# 구미호뎐 : 네이버 통합검색
# 포레스트 : 네이버 통합검색
# 이별이떠났다 : 네이버 통합검색
# 이동욱 :: 네이버 인물검색
# 김범 :: 네이버 인물검색
# 김정난 :: 네이버 인물검색
# 안길강 :: 네이버 인물검색
# 이태리 :: 네이버 인물검색
# 탤런트 황희 :: 네이버 인물검색
# 김용지 :: 네이버 인물검색
# 김수진 :: 네이버 인물검색
# 주석태 :: 네이버 인물검색
# 송영규 :: 네이버 인물검색
# 김희정 :: 네이버 인물검색
# 정이서 :: 네이버 인물검색
# 김강민 :: 네이버 인물검색
# 장원형 :: 네이버 인물검색
# 임기홍 :: 네이버 인물검색
# 이규형 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2210911607%22%7D&pkid=57&os=10911607&query=%EA%B5%AC%EB%AF%B8%ED%98%B8%EB%8E%90
# 타인은지옥이다 : 네이버 통합검색
# 진심이닿다 : 네이버 통합검색
# 임시완 :: 네이버 인물검색
# 이정은 :: 네이버 인물검색
# 영화배우 이현욱 :: 네이버 인물검색
# 박종환 :: 네이버 인물검색
# 이중옥 :: 네이버 인물검색
# 안은진 :: 네이버 인물검색
# 김지은 :: 네이버 인물검색
# 차래형 :: 네이버 인물검색
# 현봉식 :: 네이버 인물검색
# 김한종 :: 네이버 인물검색
# 오혜원 :: 네이버 인물검색
# 송욱경 :: 네이버 인물검색
# 이석 :: 네이버 인물검색
# 최찬호 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229329914%22%7D&pkid=57&os=9329914&query=%ED%83%80%EC%9D%B8%EC%9D%80%EC%A7%80%EC%98%A5%EC%9D%B4%EB%8B%A4
# 런온 : 네이버 통합검색
# 왕은사랑한다 : 네이버 통합검색
# 드라마미생 : 네이버 통합검색
# 트라이앵글 : 네이버 통합검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2213942398%22%7D&pkid=57&os=13942398&query=%EB%9F%B0%EC%98%A8
# drama : 20, actors : 85 are saved in google_drive
# drama : 20, actors : 85 are saved in local_drive
# 로스쿨 : 네이버 통합검색
# 한번다녀왔습니다 : 네이버 통합검색
# 반의반 : 네이버 통합검색
# 나홀로그대 : 네이버 통합검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2216091562%22%7D&pkid=57&os=16091562&query=%EB%A1%9C%EC%8A%A4%EC%BF%A8
# drama : 24, actors : 85 are saved in google_drive
# drama : 24, actors : 85 are saved in local_drive
# 선배그립스틱바르지마요 : 네이버 통합검색
# 써치 : 네이버 통합검색
# 모범형사 : 네이버 통합검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214261794%22%7D&pkid=57&os=14261794&query=%EC%84%A0%EB%B0%B0%EA%B7%B8%EB%A6%BD%EC%8A%A4%ED%8B%B1%EB%B0%94%EB%A5%B4%EC%A7%80%EB%A7%88%EC%9A%94
# drama : 27, actors : 85 are saved in google_drive
# drama : 27, actors : 85 are saved in local_drive
# 낭만닥터김사부2 : 네이버 통합검색
# 한석규 :: 네이버 인물검색
# 안효섭 :: 네이버 인물검색
# 이성경 :: 네이버 인물검색
# 김주헌 :: 네이버 인물검색
# 탤런트 신동욱 :: 네이버 인물검색
# 소주연 :: 네이버 인물검색
# 윤나무 :: 네이버 인물검색
# 김홍파 :: 네이버 인물검색
# 진경 :: 네이버 인물검색
# 임원희 :: 네이버 인물검색
# 변우민 :: 네이버 인물검색
# 김민재 :: 네이버 인물검색
# 고상호 :: 네이버 인물검색
# 박효주 :: 네이버 인물검색
# 배명진 :: 네이버 인물검색
# 최진호 :: 네이버 인물검색
# 정지안 :: 네이버 인물검색
# 씨스타 보라 :: 네이버 인물검색
# 서영 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229844162%22%7D&pkid=57&os=9844162&query=%EB%82%AD%EB%A7%8C%EB%8B%A5%ED%84%B0%EA%B9%80%EC%82%AC%EB%B6%802
# 왓쳐 : 네이버 통합검색
# 낭만닥터김사부1 : 네이버 통합검색
# 비밀의문 : 네이버 통합검색
# 뿌리깊은나무 : 네이버 통합검색
# 배우 서강준 :: 네이버 인물검색
# 김현주 :: 네이버 인물검색
# 허성태 :: 네이버 인물검색
# 박주희 :: 네이버 인물검색
# 주진모 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229594210%22%7D&pkid=57&os=9594210&query=%EC%99%93%EC%B3%90
# 날씨가좋으면찾아가겠어요 : 네이버 통합검색
# 제3의매력 : 네이버 통합검색
# 너도인간이니 : 네이버 통합검색
# 안투라지 : 네이버 통합검색
# 박민영 :: 네이버 인물검색
# 문정희 :: 네이버 인물검색
# 이재욱 :: 네이버 인물검색
# 임세미 :: 네이버 인물검색
# 김환희 :: 네이버 인물검색
# 추예진 :: 네이버 인물검색
# 강신일 :: 네이버 인물검색
# 남기애 :: 네이버 인물검색
# 이태형 :: 네이버 인물검색
# 윤상화 :: 네이버 인물검색
# 이선희 :: 네이버 인물검색
# 이봉련 :: 네이버 인물검색
# 이영석 :: 네이버 인물검색
# 탤런트 김영대 :: 네이버 인물검색
# 양혜지 :: 네이버 인물검색
# 김대건 :: 네이버 인물검색
# 한창민 :: 네이버 인물검색
# 황건 :: 네이버 인물검색
# 진희경 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2210012401%22%7D&pkid=57&os=10012401&query=%EB%82%A0%EC%94%A8%EA%B0%80%EC%A2%8B%EC%9C%BC%EB%A9%B4%EC%B0%BE%EC%95%84%EA%B0%80%EA%B2%A0%EC%96%B4%EC%9A%94
# 그녀의사생활 : 네이버 통합검색
# 김비서가왜그럴까 : 네이버 통합검색
# 김재욱 :: 네이버 인물검색
# 박진주 :: 네이버 인물검색
# 가수ONE :: 네이버 인물검색
# 홍서영 :: 네이버 인물검색
# 김보라 :: 네이버 인물검색
# 맹상훈 :: 네이버 인물검색
# 김선영 :: 네이버 인물검색
# 서예화 :: 네이버 인물검색
# 정원창 :: 네이버 인물검색
# 임지규 :: 네이버 인물검색
# 유용민 :: 네이버 인물검색
# 박명신 :: 네이버 인물검색
# 이일화 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229104669%22%7D&pkid=57&os=9104669&query=%EA%B7%B8%EB%85%80%EC%9D%98%EC%82%AC%EC%83%9D%ED%99%9C
# 손더게스트 : 네이버 통합검색
# 사랑의온도 : 네이버 통합검색
# 보이스시즌1 : 네이버 통합검색
# 김동욱 :: 네이버 인물검색
# 정은채 :: 네이버 인물검색
# 안내상 :: 네이버 인물검색
# 이원종 :: 네이버 인물검색
# 박호산 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228185211%22%7D&pkid=57&os=8185211&query=%EC%86%90%EB%8D%94%EA%B2%8C%EC%8A%A4%ED%8A%B8
# 그남자의기억법 : 네이버 통합검색
# 특별근로감독관조장풍 : 네이버 통합검색
# 자체발광오피스 : 네이버 통합검색
# 라이더스내일을잡아라 : 네이버 통합검색
# 문가영 :: 네이버 인물검색
# 윤종훈 :: 네이버 인물검색
# 김슬기 :: 네이버 인물검색
# 이주빈 :: 네이버 인물검색
# 김창완 :: 네이버 인물검색
# 길해연 :: 네이버 인물검색
# 장영남 :: 네이버 인물검색
# 이승준 :: 네이버 인물검색
# 차광수 :: 네이버 인물검색
# 연극배우이수미 :: 네이버 인물검색
# 유지수 :: 네이버 인물검색
# 지일주 :: 네이버 인물검색
# 장인섭 :: 네이버 인물검색
# 업텐션 이진혁 :: 네이버 인물검색
# 신주협 :: 네이버 인물검색
# 장이정 :: 네이버 인물검색
# 박지원 :: 네이버 인물검색
# 걸스데이 유라 :: 네이버 인물검색
# SF9 로운 :: 네이버 인물검색
# 김선호 :: 네이버 인물검색
# 신동미 :: 네이버 인물검색
# 양파 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2210443829%22%7D&pkid=57&os=10443829&query=%EA%B7%B8%EB%82%A8%EC%9E%90%EC%9D%98%EA%B8%B0%EC%96%B5%EB%B2%95
# 여신강림 : 네이버 통합검색
# 으라차차와이키키2 : 네이버 통합검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214315917%22%7D&pkid=57&os=14315917&query=%EC%97%AC%EC%8B%A0%EA%B0%95%EB%A6%BC
# drama : 47, actors : 168 are saved in google_drive
# drama : 47, actors : 168 are saved in local_drive
# 펜트하우스 : 네이버 통합검색
# 내사랑치유기 : 네이버 통합검색
# 이리와안아줘 : 네이버 통합검색
# 이지아 :: 네이버 인물검색
# 김소연 :: 네이버 인물검색
# 유진 :: 네이버 인물검색
# 엄기준 :: 네이버 인물검색
# 신은경 :: 네이버 인물검색
# 봉태규 :: 네이버 인물검색
# 박은석 :: 네이버 인물검색
# 윤주희 :: 네이버 인물검색
# 하도권 :: 네이버 인물검색
# 이철민 :: 네이버 인물검색
# 김로사 :: 네이버 인물검색
# 김현수 :: 네이버 인물검색
# 진지희 :: 네이버 인물검색
# 탤런트조수민 :: 네이버 인물검색
# 한지현 :: 네이버 인물검색
# 최예빈 :: 네이버 인물검색
# 이태빈 :: 네이버 인물검색
# 나소예 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2211395090%22%7D&pkid=57&os=11395090&query=%ED%8E%9C%ED%8A%B8%ED%95%98%EC%9A%B0%EC%8A%A4
# 오늘의탐정 : 네이버 통합검색
# 나의아저씨 : 네이버 통합검색
# 설련화 : 네이버 통합검색
# 세번결혼하는여자 : 네이버 통합검색
# 최다니엘 :: 네이버 인물검색
# 박은빈 :: 네이버 인물검색
# 김원해 :: 네이버 인물검색
# 이재균 :: 네이버 인물검색
# 이주영 :: 네이버 인물검색
# 신재하 :: 네이버 인물검색
# 채지안 :: 네이버 인물검색
# 김민상 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228233221%22%7D&pkid=57&os=8233221&query=%EC%98%A4%EB%8A%98%EC%9D%98%ED%83%90%EC%A0%95
# 날아올라라나비 : 네이버 통합검색
# 저글러스 : 네이버 통합검색
# 빅맨 : 네이버 통합검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214441339%22%7D&pkid=57&os=14441339&query=%EB%82%A0%EC%95%84%EC%98%AC%EB%9D%BC%EB%9D%BC%EB%82%98%EB%B9%84
# drama : 57, actors : 194 are saved in google_drive
# drama : 57, actors : 194 are saved in local_drive
# 브람스를좋아하세요 : 네이버 통합검색
# 스토브리그 : 네이버 통합검색
# 이판사판 : 네이버 통합검색
# 청춘시대2 : 네이버 통합검색
# 김성철 :: 네이버 인물검색
# 탤런트박지현 :: 네이버 인물검색
# 이유진 :: 네이버 인물검색
# 배다빈 :: 네이버 인물검색
# 예수정 :: 네이버 인물검색
# 김종태 :: 네이버 인물검색
# 서정연 :: 네이버 인물검색
# 최대훈 :: 네이버 인물검색
# 양조아 :: 네이버 인물검색
# 안상은 :: 네이버 인물검색
# 이지원 :: 네이버 인물검색
# 탤런트 백지원 :: 네이버 인물검색
# 김학선 :: 네이버 인물검색
# 연극배우 김선화 :: 네이버 인물검색
# 이노아 :: 네이버 인물검색
# 김정영 :: 네이버 인물검색
# 고소현 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2213849511%22%7D&pkid=57&os=13849511&query=%EB%B8%8C%EB%9E%8C%EC%8A%A4%EB%A5%BC%EC%A2%8B%EC%95%84%ED%95%98%EC%84%B8%EC%9A%94
# 아스달연대기 : 네이버 통합검색
# 바람이분다 : 네이버 통합검색
# 투제니 : 네이버 통합검색
# 슬기로운감빵생활 : 네이버 통합검색
# 장동건 :: 네이버 인물검색
# 송중기 :: 네이버 인물검색
# 김지원 :: 네이버 인물검색
# 김옥빈 :: 네이버 인물검색
# 김의성 :: 네이버 인물검색
# 이도경 :: 네이버 인물검색
# 박해준 :: 네이버 인물검색
# 박병은 :: 네이버 인물검색
# 신주환 :: 네이버 인물검색
# 유태오 :: 네이버 인물검색
# 추자현 :: 네이버 인물검색
# 손숙 :: 네이버 인물검색
# 장률 :: 네이버 인물검색
# 고보결 :: 네이버 인물검색
# 박형수 :: 네이버 인물검색
# 최영준 :: 네이버 인물검색
# 이호철 :: 네이버 인물검색
# 기도훈 :: 네이버 인물검색
# 이황의 :: 네이버 인물검색
# 황민호 :: 네이버 인물검색
# 윤사봉 :: 네이버 인물검색
# 박성연 :: 네이버 인물검색
# 배기범 :: 네이버 인물검색
# 조승연 :: 네이버 인물검색
# 류시현 :: 네이버 인물검색
# 정석용 :: 네이버 인물검색
# 김호정 :: 네이버 인물검색
# 박진 :: 네이버 인물검색
# 양경원 :: 네이버 인물검색
# 고나희 :: 네이버 인물검색
# 송재룡 :: 네이버 인물검색
# 김비비 :: 네이버 인물검색
# 송종호 :: 네이버 인물검색
# 안혜원 :: 네이버 인물검색
# 닉쿤 :: 네이버 인물검색
# 태원석 :: 네이버 인물검색
# 조병규 :: 네이버 인물검색
# 김도현 :: 네이버 인물검색
# 카라타 에리카 :: 네이버 인물검색
# 심은우 :: 네이버 인물검색
# 하준 :: 네이버 인물검색
# 정동훈 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228246663%22%7D&pkid=57&os=8246663&query=%EC%95%84%EC%8A%A4%EB%8B%AC%EC%97%B0%EB%8C%80%EA%B8%B0
# 슈츠 : 네이버 통합검색
# 신사의품격 : 네이버 통합검색
# 박형식 :: 네이버 인물검색
# 채정안 :: 네이버 인물검색
# 고성희 :: 네이버 인물검색
# 최귀화 :: 네이버 인물검색
# 김영호 :: 네이버 인물검색
# 이태선 :: 네이버 인물검색
# 이상이 :: 네이버 인물검색
# 이시원 :: 네이버 인물검색
# 손석구 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226358077%22%7D&pkid=57&os=6358077&query=%EC%8A%88%EC%B8%A0
# 힘쎈여자도봉순 : 네이버 통합검색
# 화랑 : 네이버 통합검색
# 상류사회 : 네이버 통합검색
# 박보영 :: 네이버 인물검색
# 지수 :: 네이버 인물검색
# 안우연 :: 네이버 인물검색
# 심혜진 :: 네이버 인물검색
# 유재명 :: 네이버 인물검색
# 박보미 :: 네이버 인물검색
# 황화순 :: 네이버 인물검색
# 김수연 :: 네이버 인물검색
# 전석호 :: 네이버 인물검색
# 심훈기 :: 네이버 인물검색
# 김민교 :: 네이버 인물검색
# 김기무 :: 네이버 인물검색
# 설인아 :: 네이버 인물검색
# 윤예희 :: 네이버 인물검색
# 최무인 :: 네이버 인물검색
# 오순태 :: 네이버 인물검색
# 양주호 :: 네이버 인물검색
# 탤런트 최형 :: 네이버 인물검색
# 김원석 :: 네이버 인물검색
# 장미관 :: 네이버 인물검색
# 윤상현 :: 네이버 인물검색
# 권혁수 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223619390%22%7D&pkid=57&os=3619390&query=%ED%9E%98%EC%8E%88%EC%97%AC%EC%9E%90%EB%8F%84%EB%B4%89%EC%88%9C
# 어비스 : 네이버 통합검색
# 오나의귀신님 : 네이버 통합검색
# 영화배우 이성재 :: 네이버 인물검색
# 한소희 :: 네이버 인물검색
# 권수현 :: 네이버 인물검색
# 윤유선 :: 네이버 인물검색
# 송상은 :: 네이버 인물검색
# 이대연 :: 네이버 인물검색
# 하성광 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228692982%22%7D&pkid=57&os=8692982&query=%EC%96%B4%EB%B9%84%EC%8A%A4
# 검사내전 : 네이버 통합검색
# 이선균 :: 네이버 인물검색
# 정려원 :: 네이버 인물검색
# 이상희 :: 네이버 인물검색
# 전성우 :: 네이버 인물검색
# 백현주 :: 네이버 인물검색
# 안창환 :: 네이버 인물검색
# 정재성 :: 네이버 인물검색
# 김용희 :: 네이버 인물검색
# 차순배 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229466816%22%7D&pkid=57&os=9466816&query=%EA%B2%80%EC%82%AC%EB%82%B4%EC%A0%84
# 이번주아내가바람을핍니다 : 네이버 통합검색
# 미스코리아 : 네이버 통합검색
# 송지효 :: 네이버 인물검색
# 이상엽 :: 네이버 인물검색
# 가수 보아 :: 네이버 인물검색
# 김희원 :: 네이버 인물검색
# 예지원 :: 네이버 인물검색
# 김강훈 :: 네이버 인물검색
# 이석준 :: 네이버 인물검색
# 박수영 :: 네이버 인물검색
# 심희섭 :: 네이버 인물검색
# 소년공화국 이수웅 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223739651%22%7D&pkid=57&os=3739651&query=%EC%9D%B4%EB%B2%88%EC%A3%BC%EC%95%84%EB%82%B4%EA%B0%80%EB%B0%94%EB%9E%8C%EC%9D%84%ED%95%8D%EB%8B%88%EB%8B%A4
# 우리사랑했을까 : 네이버 통합검색
# 러블리호러블리 : 네이버 통합검색
# 드라마스테이지b주임과러브레터 : 네이버 통합검색
# 손호준 :: 네이버 인물검색
# 구자성 :: 네이버 인물검색
# 김민준 :: 네이버 인물검색
# 탤런트 김다솜 :: 네이버 인물검색
# 엄채영 :: 네이버 인물검색
# 김영아 :: 네이버 인물검색
# 백수희 :: 네이버 인물검색
# 김병춘 :: 네이버 인물검색
# 윤성우 :: 네이버 인물검색
# 이교엽 :: 네이버 인물검색
# 이화룡 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2210524900%22%7D&pkid=57&os=10524900&query=%EC%9A%B0%EB%A6%AC%EC%82%AC%EB%9E%91%ED%96%88%EC%9D%84%EA%B9%8C
# 눈이부시게 : 네이버 통합검색
# 내뒤에테리우스 : 네이버 통합검색
# 김혜자 :: 네이버 인물검색
# 한지민 :: 네이버 인물검색
# 남주혁 :: 네이버 인물검색
# 김가은 :: 네이버 인물검색
# 정영숙 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228743150%22%7D&pkid=57&os=8743150&query=%EB%88%88%EC%9D%B4%EB%B6%80%EC%8B%9C%EA%B2%8C
# 디어마이프렌즈 : 네이버 통합검색
# 착하지않은여자들 : 네이버 통합검색
# 청담동살아요 : 네이버 통합검색
# 고현정 :: 네이버 인물검색
# 고두심 :: 네이버 인물검색
# 나문희 :: 네이버 인물검색
# 윤여정 :: 네이버 인물검색
# 박원숙 :: 네이버 인물검색
# 주현 :: 네이버 인물검색
# 신성우 :: 네이버 인물검색
# 조인성 :: 네이버 인물검색
# 이광수 :: 네이버 인물검색
# 성동일 :: 네이버 인물검색
# 장현성 :: 네이버 인물검색
# 다니엘헤니 :: 네이버 인물검색
# 남능미 :: 네이버 인물검색
# 변우석 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223037575%22%7D&pkid=57&os=3037575&query=%EB%94%94%EC%96%B4%EB%A7%88%EC%9D%B4%ED%94%84%EB%A0%8C%EC%A6%88
# 동네변호사조들호2죄와벌 : 네이버 통합검색
# 여왕의교실 : 네이버 통합검색
# 박신양 :: 네이버 인물검색
# 이민지 :: 네이버 인물검색
# 변희봉 :: 네이버 인물검색
# 최승경 :: 네이버 인물검색
# 조달환 :: 네이버 인물검색
# 이미도 :: 네이버 인물검색
# 윤주만 :: 네이버 인물검색
# 권혁 :: 네이버 인물검색
# 장하란 :: 네이버 인물검색
# 정준원 :: 네이버 인물검색
# 문수빈 :: 네이버 인물검색
# 서이숙 :: 네이버 인물검색
# 전배수 :: 네이버 인물검색
# 손병호 :: 네이버 인물검색
# 홍경 :: 네이버 인물검색
# 이지민 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%224145707%22%7D&pkid=57&os=4145707&query=%EB%8F%99%EB%84%A4%EB%B3%80%ED%98%B8%EC%82%AC%EC%A1%B0%EB%93%A4%ED%98%B82%EC%A3%84%EC%99%80%EB%B2%8C
# 동네변호사조들호1 : 네이버 통합검색
# 싸인 : 네이버 통합검색
# 강소라 :: 네이버 인물검색
# 류수영 :: 네이버 인물검색
# 박솔미 :: 네이버 인물검색
# 김갑수 :: 네이버 인물검색
# 정원중 :: 네이버 인물검색
# 황석정 :: 네이버 인물검색
# 박원상 :: 네이버 인물검색
# 김동준 :: 네이버 인물검색
# 정규수 :: 네이버 인물검색
# 장소연 :: 네이버 인물검색
# 윤복인 :: 네이버 인물검색
# 최재환 :: 네이버 인물검색
# 허정은 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223184428%22%7D&pkid=57&os=3184428&query=%EB%8F%99%EB%84%A4%EB%B3%80%ED%98%B8%EC%82%AC%EC%A1%B0%EB%93%A4%ED%98%B81
# 변혁의사랑 : 네이버 통합검색
# 맨도롱또똣 : 네이버 통합검색
# 닥터이방인 : 네이버 통합검색
# 슈퍼주니어 시원 :: 네이버 인물검색
# 공명 :: 네이버 인물검색
# 김예원 :: 네이버 인물검색
# 이재윤 :: 네이버 인물검색
# 최재성 :: 네이버 인물검색
# 견미리 :: 네이버 인물검색
# 이한위 :: 네이버 인물검색
# 황영희 :: 네이버 인물검색
# 강영석 :: 네이버 인물검색
# 서현철 :: 네이버 인물검색
# 최대철 :: 네이버 인물검색
# 최규환 :: 네이버 인물검색
# 김기두 :: 네이버 인물검색
# 정찬비 :: 네이버 인물검색
# 서이안 :: 네이버 인물검색
# 김승욱 :: 네이버 인물검색
# 이윤지 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226158154%22%7D&pkid=57&os=6158154&query=%EB%B3%80%ED%98%81%EC%9D%98%EC%82%AC%EB%9E%91
# 시네마틱드라마sf8증강콩깍지 : 네이버 통합검색
# 국민여러분 : 네이버 통합검색
# 유이 :: 네이버 인물검색
# 안세하 :: 네이버 인물검색
# 영화배우 김한나 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2213953176%22%7D&pkid=57&os=13953176&query=%EC%8B%9C%EB%84%A4%EB%A7%88%ED%8B%B1%EB%93%9C%EB%9D%BC%EB%A7%88sf8%EC%A6%9D%EA%B0%95%EC%BD%A9%EA%B9%8D%EC%A7%80
# 하나뿐인내편 : 네이버 통합검색
# 데릴남편오작두 : 네이버 통합검색
# 맨홀이상한나라의필 : 네이버 통합검색
# 최수종 :: 네이버 인물검색
# 이장우 :: 네이버 인물검색
# 나혜미 :: 네이버 인물검색
# 윤진이 :: 네이버 인물검색
# 정은우 :: 네이버 인물검색
# 박성훈 :: 네이버 인물검색
# 이두일 :: 네이버 인물검색
# 임예진 :: 네이버 인물검색
# 정재순 :: 네이버 인물검색
# 박상원 :: 네이버 인물검색
# 차화연 :: 네이버 인물검색
# 이혜숙 :: 네이버 인물검색
# 이승형 :: 네이버 인물검색
# 김추월 :: 네이버 인물검색
# 황효은 :: 네이버 인물검색
# 이용이 :: 네이버 인물검색
# 고우리 :: 네이버 인물검색
# 송원석 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228611851%22%7D&pkid=57&os=8611851&query=%ED%95%98%EB%82%98%EB%BF%90%EC%9D%B8%EB%82%B4%ED%8E%B8
# drama : 95, actors : 407 are saved in google_drive
# drama : 95, actors : 407 are saved in local_drive
# 오삼광빌라 : 네이버 통합검색
# 우아한가 : 네이버 통합검색
# 전인화 :: 네이버 인물검색
# 정보석 :: 네이버 인물검색
# 황신혜 :: 네이버 인물검색
# 진기주 :: 네이버 인물검색
# 인교진 :: 네이버 인물검색
# 한보름 :: 네이버 인물검색
# 우주소녀 보나 :: 네이버 인물검색
# 려운 :: 네이버 인물검색
# 탤런트 김시은 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2213918030%22%7D&pkid=57&os=13918030&query=%EC%98%A4%EC%82%BC%EA%B4%91%EB%B9%8C%EB%9D%BC
# 내딸금사월 : 네이버 통합검색
# 전설의마녀 : 네이버 통합검색
# 백년의유산 : 네이버 통합검색
# 백진희 :: 네이버 인물검색
# 윤현민 :: 네이버 인물검색
# 박세영 :: 네이버 인물검색
# 도상우 :: 네이버 인물검색
# 손창민 :: 네이버 인물검색
# 도지원 :: 네이버 인물검색
# 송하윤 :: 네이버 인물검색
# 이정길 :: 네이버 인물검색
# 오미연 :: 네이버 인물검색
# 이연두 :: 네이버 인물검색
# 강래연 :: 네이버 인물검색
# 김지영 :: 네이버 인물검색
# 이태우 :: 네이버 인물검색
# 박수빈 :: 네이버 인물검색
# 구승현 :: 네이버 인물검색
# 이나윤 :: 네이버 인물검색
# 이도연 :: 네이버 인물검색
# 갈소원 :: 네이버 인물검색
# 전진서 :: 네이버 인물검색
# 곽지혜 :: 네이버 인물검색
# 김소은 :: 네이버 인물검색
# 고우림 :: 네이버 인물검색
# 주아성 :: 네이버 인물검색
# 김완선 :: 네이버 인물검색
# 김호진 :: 네이버 인물검색
# 탤런트김지호 :: 네이버 인물검색
# 유재석 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%222841473%22%7D&pkid=57&os=2841473&query=%EB%82%B4%EB%94%B8%EA%B8%88%EC%82%AC%EC%9B%94
# 죽어도좋아 : 네이버 통합검색
# 식샤를합시다3비긴즈 : 네이버 통합검색
# 미씽나인 : 네이버 통합검색
# 강지환 :: 네이버 인물검색
# 류현경 :: 네이버 인물검색
# 이병준 :: 네이버 인물검색
# 김민재 :: 네이버 인물검색
# 탤런트 정민아 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228725349%22%7D&pkid=57&os=8725349&query=%EC%A3%BD%EC%96%B4%EB%8F%84%EC%A2%8B%EC%95%84
# 조선생존기 : 네이버 통합검색
# 작은신의아이들 : 네이버 통합검색
# 몬스터 : 네이버 통합검색
# 서지석 :: 네이버 인물검색
# 경수진 :: 네이버 인물검색
# 박세완 :: 네이버 인물검색
# 한재석 :: 네이버 인물검색
# 윤지민 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229576455%22%7D&pkid=57&os=9576455&query=%EC%A1%B0%EC%84%A0%EC%83%9D%EC%A1%B4%EA%B8%B0
# 어쩌다가족 : 네이버 통합검색
# 이름없는여자 : 네이버 통합검색
# 오현경 :: 네이버 인물검색
# 이본 :: 네이버 인물검색
# CLC 권은빈 :: 네이버 인물검색
# 안드레아스 바르사코풀로스 :: 네이버 인물검색
# 길은혜 :: 네이버 인물검색
# 이승용 :: 네이버 인물검색
# 펜타곤 여원 :: 네이버 인물검색
# 조은비 :: 네이버 인물검색
# 이예린 :: 네이버 인물검색
# 가수 최문희 :: 네이버 인물검색
# 송보은 :: 네이버 인물검색
# 제시 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2211852757%22%7D&pkid=57&os=11852757&query=%EC%96%B4%EC%A9%8C%EB%8B%A4%EA%B0%80%EC%A1%B1
# drama : 108, actors : 465 are saved in google_drive
# drama : 108, actors : 465 are saved in local_drive
# drama : 108, actors : 465 are saved in google_drive
# drama : 108, actors : 465 are saved in local_drive
# 디어엠 : 네이버 통합검색
# 배드파파 : 네이버 통합검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2216048793%22%7D&pkid=57&os=16048793&query=%EB%94%94%EC%96%B4%EC%97%A0
# drama : 110, actors : 465 are saved in google_drive
# drama : 110, actors : 465 are saved in local_drive
# 연애는귀찮지만외로운건싫어 : 네이버 통합검색
# 배우 지현우 :: 네이버 인물검색
# 김소은 :: 네이버 인물검색
# 건일 :: 네이버 인물검색
# B1A4 공찬 :: 네이버 인물검색
# 한지완 :: 네이버 인물검색
# 김산호 :: 네이버 인물검색
# 배우손지현 :: 네이버 인물검색
# 차수연 :: 네이버 인물검색
# 하영 :: 네이버 인물검색
# 노지훈 :: 네이버 인물검색
# 조현영 :: 네이버 인물검색
# 브라운 아이드 걸스 나르샤 :: 네이버 인물검색
# 임현수 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214256545%22%7D&pkid=57&os=14256545&query=%EC%97%B0%EC%95%A0%EB%8A%94%EA%B7%80%EC%B0%AE%EC%A7%80%EB%A7%8C%EC%99%B8%EB%A1%9C%EC%9A%B4%EA%B1%B4%EC%8B%AB%EC%96%B4
# 슬플때사랑한다 : 네이버 통합검색
# 사생결단로맨스 : 네이버 통합검색
# 도둑놈도둑님 : 네이버 통합검색
# 원티드 : 네이버 통합검색
# 박한별 :: 네이버 인물검색
# 왕빛나 :: 네이버 인물검색
# 박하나 :: 네이버 인물검색
# 탤런트 문희경 :: 네이버 인물검색
# 고주원 :: 네이버 인물검색
# 황정인 :: 네이버 인물검색
# 박상신 :: 네이버 인물검색
# 김예령 :: 네이버 인물검색
# 김윤주 :: 네이버 인물검색
# 안정훈 :: 네이버 인물검색
# 강성욱 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228940569%22%7D&pkid=57&os=8940569&query=%EC%8A%AC%ED%94%8C%EB%95%8C%EC%82%AC%EB%9E%91%ED%95%9C%EB%8B%A4
# 보그맘 : 네이버 통합검색
# 애인있어요 : 네이버 통합검색
# 양동근 :: 네이버 인물검색
# 아이비 :: 네이버 인물검색
# 최여진 :: 네이버 인물검색
# 황보라 :: 네이버 인물검색
# 정이랑 :: 네이버 인물검색
# 조연호 :: 네이버 인물검색
# 최정원 :: 네이버 인물검색
# 권현빈 :: 네이버 인물검색
# 정지훈 :: 네이버 인물검색
# 김도혜 :: 네이버 인물검색
# 송지우 :: 네이버 인물검색
# 나인뮤지스 박경리 :: 네이버 인물검색
# 김준현 :: 네이버 인물검색
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226202062%22%7D&pkid=57&os=6202062&query=%EB%B3%B4%EA%B7%B8%EB%A7%98

# %%
### def get_drama_urls_test(actor_url):
    #pre_len_drama_set = len(drama)
    drama_url_list = []
    soup = get_soup(actor_url)
    result = soup.find('ul',{'id':'"listUI_76'})
    try:
        drama_data = result.text.split('oPagingListUi76.displayResult(')[1].split('}]')[0]
    except:
        logging.info('actor_url : {}, no displayResult, in {}'.format(actor_url, get_drama_urls.__name__))
        return None
    for i in drama_data.split('\"onair_url\": \"'):
        if i.startswith('https://search.naver.com/search'):
            drama_url = i.split("\"")[0]
            if isdrama(drama_url):
                drama_url_list.append(drama_url) 
                #drama.add(drama_url)
                print_title(drama_url)
    
    if len(drama_url_list) == 0:
        return None
    #if pre_len_drama_set == len(drama):
    #    return None
    
    return drama_url_list

# %%
get_drama_urls_test(new_act)
# Out:
# 카이로스 : 네이버 통합검색
# 배가본드 : 네이버 통합검색
# 퍼퓸 : 네이버 통합검색
# 황후의품격 : 네이버 통합검색
# ['https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214012462%22%7D&pkid=57&os=14012462&query=%EC%B9%B4%EC%9D%B4%EB%A1%9C%EC%8A%A4',
#  'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226487748%22%7D&pkid=57&os=6487748&query=%EB%B0%B0%EA%B0%80%EB%B3%B8%EB%93%9C',
#  'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%229591019%22%7D&pkid=57&os=9591019&query=%ED%8D%BC%ED%93%B8',
#  'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228640383%22%7D&pkid=57&os=8640383&query=%ED%99%A9%ED%9B%84%EC%9D%98%ED%92%88%EA%B2%A9']

# %%
soup = get_soup(new_act)
name = soup.title.text.split()[0]
text = soup.find('ul', {'id':"listUI_76"}).parent.next_sibling.next.text
text = text.split('setOnairInfo(contentsid)')[1]
characterLink = text.split('characterLink = \'')

# %%
drama_data_dict = {}
def drama_data(actor_url):
    soup = get_soup(actor_url)
    name = soup.title.text.split()[0]
    text = soup.find('ul', {'id':"listUI_76"}).parent.next_sibling.next.text
    try:
        text = text.split('setOnairInfo(contentsid)')[1]
    except:
        return None
    characterLink = text.split('characterLink = \'')
    drama_characters = {}
    for i in text.split('characterName')[1:]:
        
        if 'http://search.naver.com/search' in i:
            data_parts = i.split(';')
            character = data_parts[0].split()[-1].strip('\'')
            character_url = data_parts[1].split()[-1].strip('\'')
            role = data_parts[2].split()[-1]
            role = re.sub('[\(\)\']', '', role)
            soup = get_soup(character_url)
            drama_title = get_drama_title(character, soup)
            character_desc = get_character_desc(soup)
            
            drama_characters[drama_title] = (role, character_desc) 

            #print(character, character_url, role, drama_title, character_desc, name)
            #print(drama_characters)
    
    drama_data_dict[name] = drama_characters
    return drama_data_dict

drama_data(new_act)
# Out:
# {'신성록': {'카이로스': ('주연',
#    "유중건설 최연소 이사. 다시 모든 것이 무너져 내린다고 해도. '성공한' 인생이 되기 위해 무슨 기회든 놓치지 않았고 똑똑한 동시에 부지런했다. 무슨 일이든 제 손을 거치지 않으면 마음을 놓지 않았고, 사람이 아닌 상황과 숫자만을 믿었다. 모든 관계는 효율 위주라 제 말귀를 못 알아듣는 이와는 함께 일하지 않았다. 이만하면 성공한 삶이었다."),
#   '배가본드': ('주연',
#    '병원장인 아버지와 대학교수 어머니를 둔 흔히 말하는 금수저 출신이다. 정국표 정권이 들어서고 나서부터 조직의 색깔도 바뀌었다. 파벌싸움과 알력다툼이 국정원을 갈라놓고 있었다. 진짜 요원들은 한직으로 밀려났고 정치꾼과 모사꾼들이 조직을 장악했다. 그의 포지션도 위태로웠다. 비행기 테러의 공범, 잡기 위해 모로코에 급파됐다. 거기서 그는 차달건을 처음 만났다.'),
#   '퍼퓸': ('주연',
#    '창의적으로 섬세하게 병들어버린 파워 관종 패션 디자이너. 삶의 본질적 아름다움을 꿰뚫는 심미안을 가진 나는 명실상부 대한민국 최고의 디자이너다. 독창적이고 창조적이며 심오한 내면세계를 가진 예술가로, 인간세계에 천상의 아름다움을 전하는 전령사, 헤르메스와 같은 존재라 하겠다. 수려한 이목구비, 체지방 9.7%의 빈틈없는 몸매, 중저음의 기품 있는 목소리까지... 이 모든 것을 갖춘 나의 존재 자체가 하나의 예술작품이라 해도 과언이 아니겠지.'),
#   '황후의품격': ('주연',
#    '대한제국의 황제. 절대 권력자. 국민들의 추앙을 받는 카리스마 있는, 마성의 남자. 잘생긴 외모와 화려한 언변을 자랑하지만, 내면은 비리와 부패로 찌들어 있고, 병적인 여성편력으로 매일 밤 여자가 바뀌지만 사람들에게는 죽은 황후를 못 잊고 그리워하는 로맨티시스트로 알려져 있다. 비취도를 찾았다가, 민유라의 유혹으로 뜨거운 시간을 보내게 되고 만취 상태로 운전하다 갑자기 뛰어든 나왕식의 엄마를 차로 치고 도망친다.'),
#   '리턴': ('주연',
#    '돈과 권력의 결합으로 무소불위 집안을 배경으로 둔 황태자 4인방 중 한 명. 물려받을 재산만으로도 평생 호의호식할 수 있었겠지만, 스마트폰 앱을 개발하여 지금은 아버지의 후광 없이 주식상장까지 하며 떠오르는 올해의 기업인 상을 받기도 했다. 그는 노력파이기보다 직관이 좋은 천재 형이라 놀 거 다 놀면서 일도 잘한다. 악마적 본능에 충실한 타입, 그러나 그럴싸하게 포장할 줄도 아는 인물.'),
#   '죽어야사는남자': ('주연',
#    '백작 사위. 재미로 봤던 점쟁이 말대로라면 영부인의 팔자를 타고 태어났다. 대통령도 아니고, 영부인...? 남자가?? 잘생긴 얼굴 덕에 수많은 여학생들의 시선을 사로잡았다. 그러나 지금 그는 평범하고 소심한 제2금융권 은행원으로 연봉 10%가 오를 날을 손꼽아 기다리는 대신, 인생 한 방을 꿈꾸며 로또를 산다. 든든한 처갓집 배경으로 승승장구하는 친구들을 보고 있자니 배가 아프다.'),
#   '공항가는길': ('주연',
#    "공격적으로 대쉬해서 수아와 순식간에 결혼했지만 엄격한 성격 탓에 이게 부부인지, 상하관계인지. 수아가 힘들어하는 지점이다. 독립성을 중시하고, 능력 없는 사람은 은근 무시한다. 자식이라고는 딸 효은이 뿐인데, 다른 건 몰라도 교육에 대해서는 욕심이 있다. '정보력' 운운하는 한국식 교육은 싫고, 세계 곳곳에서 활동하는 글로벌한, 멋진 딸이 되었으면 한다."),
#   '왕의얼굴': ('주연',
#    '백정의 자식으로 태어나 천하게 구르며 살았지만, 행복했다. 천민들이 모여 사는 마을 아사 골에 역병이 돌았을 때도, 동분서주 뛰어다니며 마을 사람들을 돌봤다.'),
#   '라이어게임': ('주연',
#    '라이어 게임 쇼 호스트. ‘지는 승부는 하지 않는다’가 모토인, 예리한 분석력과 예측력을 겸비한 국내 최고의 애널리스트. 검은 슈트와 실크 셔츠가 피부처럼 잘 어울리는 남자로 그 속에 강인한 근육질의 몸을 감추고 있다. 누구나 첫눈에 호감을 가질만한 외모, 논리적이고 유려한 언변에, 어떤 사람이든 자신의 뜻대로 움직일 수 있다는 듯 자심감이 눈빛에 배어있다.'),
#   '트로트의연인': ('주연',
#    '기획사 샤인스타의 젊은 사장. 상속 포기 각서를 빌미로 아버지 조사장의 강요에 못 이겨 1년 동안 기획사 샤인스타를 경영하게 된다. 큰 그림을 그릴 줄 아는 타고난 사업가.'),
#   '별에서온그대': ('조연',
#    'S&C;그룹 후계자. 겉으로 보기에는 아주 멀쩡한, 유능한 비즈니스맨. 그러나 철저한 가면 속에 가려진 전형적인 사이코패스.'),
#   '이웃집웬수': ('주연',
#    '이태리 레스토랑 경영. 잘생긴 외모에 자유분방한 성격. 아버진 종합병원의 병원장이며 엄마도 산부인과 의사이다.'),
#   '내인생의황금기': ('주연',
#    '잘난 외모, 뛰어난 패션 감각, 명석한 머리 등 객관적으로 분명히 빼어나고 잘났다. 문제는 지가 잘난 것을 너무 잘 알아 오만불손 건방이 하늘을 찌른다. 타인에 대한 배려도 없고, 이해심도 없다. 그래서 쓸데없는 동정이나 오버 액션도 없다.'),
#   '아빠셋엄마하나': ('주연',
#    '결혼이 하고 싶다. 아기도 낳고 싶다. 근데 왜 여자들은 경찰을 싫어하는 거야! 신세대 형사답게 한 외모 하며, 몸도 좋다. 하지만 남방 단추 꼭 끝까지 잠근다. 섹시한 여자 피의자라도 오면, 가슴이 콩당콩당 손 덜덜 떨면서 수갑 채운다. 여자만 만나면 발 냄새 날까봐 가까이 가지도 못한다. 형사들이 무식할 거라는 편견을 가장 싫어하는데...실은 무식하다.'),
#   '유혹의기술': ('주연',
#    "96번의 퇴짜를 맞았던, 소심한 우리의 주인공. 유혹 고수 김선생을 만나 '유혹의 절대 고수'로 변신한다."),
#   '고맙습니다': ('주연',
#    '푸른도 최고의 킹카. 영신의 첫사랑. 봄이의 친아버지. 푸른도 손꼽히는 갑부집 아들로 푸른도 소녀들의 절대 동경의 대상이었던 나는 군 입대를 앞둔 불안한 시기의 객기로 영신과 잠자리를 했다. 군대에서 면회 온 부모님을 통해 영신이 딸아이 하나를 낳은 미혼모가 되었다는 얘기를 들었지만, 어머니에 따르면 그것은 소문일 뿐이라는데... 에라 모르겠다. 내 새끼든 아니든 나랑 무슨 상관이야.'),
#   '하이에나': ('주연',
#    '모든 운동에 만능이고, 꾸미지 않아도 언제나 깔끔하고 세련된 느낌. 합리적인 이성과 따뜻한 감성을 가진 매력남.')}}

# %%
actors = list(actors)[:2]

# %%
for a in actors:
    print(a)
# Out:
# https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query=%EB%B0%A9%EC%9D%80%ED%9D%AC&os=94386&ie=utf8&key=PeopleService
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226136977%22%7D&pkid=57&os=6136977&query=%EB%9E%80%EC%A0%9C%EB%A6%AC%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80

# %%
drama_data_dict

# %%
actors
# Out:
# ['https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query=%EB%B0%A9%EC%9D%80%ED%9D%AC&os=94386&ie=utf8&key=PeopleService',
#  'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226136977%22%7D&pkid=57&os=6136977&query=%EB%9E%80%EC%A0%9C%EB%A6%AC%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80']

# %%
with open('/Users/daeyeop/Work/KBS Drama project/Data/drama.json', 'r', encoding='utf-8') as f:
    actors = json.load(f)

for a in actors[:10]:
    print(a)
# Out:
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%225870350%22%7D&pkid=57&os=5870350&query=%EB%B0%A5%EC%83%81%EC%B0%A8%EB%A6%AC%EB%8A%94%EB%82%A8%EC%9E%90
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%222436447%22%7D&pkid=57&os=2436447&query=%EB%84%88%EB%A5%BC%EC%82%AC%EB%9E%91%ED%95%9C%EC%8B%9C%EA%B0%84
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223475448%22%7D&pkid=57&os=3475448&query=%EB%81%9D%EC%97%90%EC%84%9C%EB%91%90%EB%B2%88%EC%A7%B8%EC%82%AC%EB%9E%91
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%226136977%22%7D&pkid=57&os=6136977&query=%EB%9E%80%EC%A0%9C%EB%A6%AC%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%22667213%22%7D&pkid=57&os=667213&query=%EB%B9%9B%EA%B3%BC%EA%B7%B8%EB%A6%BC%EC%9E%90
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214295899%22%7D&pkid=57&os=14295899&query=%EC%8B%9C%EB%84%A4%EB%A7%88%ED%8B%B1%EB%93%9C%EB%9D%BC%EB%A7%88sf8%EB%B8%94%EB%A7%81%ED%81%AC
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%2214344323%22%7D&pkid=57&os=14344323&query=%EC%96%B8%EB%8D%94%EC%BB%A4%EB%B2%84
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%222016349%22%7D&pkid=57&os=2016349&query=%ED%94%BC%EB%85%B8%ED%82%A4%EC%98%A4
# https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query=%EB%85%B8%EC%88%98%EC%82%B0%EB%82%98&os=239722&ie=utf8&key=PeopleService
# https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bjkw&x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%222463361%22%7D&pkid=57&os=2463361&query=%EC%9A%B8%EC%A7%80%EC%95%8A%EB%8A%94%EC%83%88

# %%
drama2 = set([1,2,3])

1 in drama2
# Out:
# True
